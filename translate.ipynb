# %%
import json
import argostranslate.package
import argostranslate.translate

from_code = "en"
to_code = "es"

argostranslate.package.update_package_index()
available_packages = argostranslate.package.get_available_packages()
package_to_install = next(
    filter(
        lambda x: x.from_code == from_code and x.to_code == to_code, available_packages
    )
)
argostranslate.package.install_from_path(package_to_install.download())

# %%
exercises = {}

with open('./json/exercises.json') as json_file:
    exercises = json.load(json_file)

# %%
for ex_id in exercises.keys():
    name_en_us = exercises[ex_id]['name_en_us']
    name_es = argostranslate.translate.translate("Hello", from_code, to_code) 
    print(name_es)
# Out:
# Barbell Curl
# Barbell Bench Press
# Barbell Squat
# Barbell Stiff Leg Deadlifts
# Barbell Hip Thrust
# Barbell Behind The Back Wrist Curl
# Barbell Deadlift
# Barbell Laying Triceps Extensiones
# Barbell Bent Over Row
# Barbell Wrist Curl
# Barbell Incline Bench Press
# Barbell Roll Outs
# Barbell Calf Raises
# Barbell Close Grip Bench Press
# Barbell Curtsy Lunge
# Barbell Silverback Shrug
# Barbell Landmine Side Bend
# Barbell Bulgarian Squat de división
# Barbell Floor Press
# Barbell Front Raise
# Barbell Front Squat Olympic
# Barbell Front Squat Bodybuilding
# Barbell High Bar Good Morning
# Barbell Low Bar Buenos días
# Barbell Overhead Press
# Barbell Upright Row
# Barbell Sumo Deadlift
# Barbell Staggered Deadlift
# Barbell Skullcrusher
# Barbell Single Leg Deadlift
# Barbell Situp
# Barbell Reverse Curl
# Barbell Overhead Tricep Extension
# Barbell Romanian Deadlift
# Barbell High Bar Squat
# Barbell Low Bar Squat
# Barbell Calf Jump
# Barbell Coan Deadlift
# ...
